# %%
import pandas as pd
import shutil

# %%
basePath = "/home/birdo/MachineLearning/"
sourcePath = basePath+"Data/freefield1010/wav/"
destPath = basePath + "Vogelgeluiden/no bird/geluiden/"

# %%
df = pd.read_csv(basePath + "Data/freefield1010/ff1010bird_metadata_2018.csv")

# %%
df
# Out:
#       itemid   datasetid  hasbird
# 0      64486  ff1010bird        0
# 1       2525  ff1010bird        0
# 2      44981  ff1010bird        0
# 3     101323  ff1010bird        0
# 4     165746  ff1010bird        0
# ...      ...         ...      ...
# 7685  168059  ff1010bird        0
# 7686  164922  ff1010bird        0
# 7687   80789  ff1010bird        1
# 7688  104733  ff1010bird        1
# 7689   40565  ff1010bird        0
#
# [7690 rows x 3 columns]

# %%
df_background = df[df.hasbird ==0 ]
df_background
# Out:
#       itemid   datasetid  hasbird
# 0      64486  ff1010bird        0
# 1       2525  ff1010bird        0
# 2      44981  ff1010bird        0
# 3     101323  ff1010bird        0
# 4     165746  ff1010bird        0
# ...      ...         ...      ...
# 7683   95027  ff1010bird        0
# 7684   80708  ff1010bird        0
# 7685  168059  ff1010bird        0
# 7686  164922  ff1010bird        0
# 7689   40565  ff1010bird        0
#
# [5755 rows x 3 columns]

# %%
no_birds_files = df_background.itemid.values
no_birds_files
# Out:
# array([ 64486,   2525,  44981, ..., 168059, 164922,  40565])

# %%
for no_bird_file in no_birds_files:
    filePath = sourcePath+str(no_bird_file)+".wav"
    shutil.copy(filePath, destPath)
